# %% [markdown]
# # I/O
#
# In this example, we will show how to load various input types and to extract relevance informations

# %%
import numpy as np
from copy import deepcopy
from pymatgen.core import Structure
from pymatgen.io.ase import AseAtomsAdaptor

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent.parent

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT)) 

from muonscripts.constants import constants
from muonscripts.io_tools.read import read_cif
from muonscripts.io_tools.read import read_from_file

import muonscripts.io_tools as ios
import muonscripts.io_tools.read_qe  as qe
import muonscripts.io_tools.read_elk  as elk

from muonscripts.io_tools.load_relax import load_relax
from muonscripts.io_tools.load_relax import save_relax_results
from muonscripts.io_tools.load_relax import load_relax_results
from muonscripts.io_tools.find_qe_files import select_groups
from muonscripts.io_tools.find_qe_files import get_relax_after_run
from muonscripts.io_tools.find_qe_files import print_relax_summary
from muonscripts.io_tools.find_qe_files import load_relax_from_folder


# ROOT, sys.path
print("Planck's Constant:", constants.H_PLANCK)
# Out:
# Planck's Constant: 6.62607015e-34

# %%
import os
dpath = '/home/misah/projects/muonscripts/examples/data'

# %% [markdown]
# load input structure formats

# %%
file=os.path.join(dpath, 'CaF2.cif')
read_cif(file)
read_from_file(file)
# Out:
# /home/misah/.virtualenvs/pyqm/lib/python3.10/site-packages/ase/io/cif.py:411: UserWarning: crystal system 'cubic' is not interpreted for space group Spacegroup(225, setting=1). This may result in wrong setting!
#   warnings.warn(
# Atoms(symbols='Ca4F8', pbc=True, cell=[5.45095, 5.45095, 5.45095], spacegroup_kinds=...)

# %%
file=os.path.join(dpath, 'CaF2.vasp')
read_cif(file)
read_from_file(file)
# Out:
# Atoms(symbols='Ca4F8', pbc=True, cell=[5.4509501457, 5.4509501457, 5.4509501457])

# %%
file=os.path.join(dpath, 'CaF2.vasp')
Structure.from_file(file)
# Out:
# Structure Summary
# Lattice
#     abc : 5.4509501457 5.4509501457 5.4509501457
#  angles : 90.0 90.0 90.0
#  volume : 161.96330486922204
#       A : np.float64(5.4509501457) np.float64(0.0) np.float64(0.0)
#       B : np.float64(0.0) np.float64(5.4509501457) np.float64(0.0)
#       C : np.float64(0.0) np.float64(0.0) np.float64(5.4509501457)
#     pbc : True True True
# PeriodicSite: Ca (2.725, 2.725, 2.725) [0.5, 0.5, 0.5]
# PeriodicSite: Ca (2.725, 0.0, 0.0) [0.5, 0.0, 0.0]
# PeriodicSite: Ca (0.0, 2.725, 0.0) [0.0, 0.5, 0.0]
# PeriodicSite: Ca (0.0, 0.0, 2.725) [0.0, 0.0, 0.5]
# PeriodicSite: F (1.363, 4.088, 4.088) [0.25, 0.75, 0.75]
# PeriodicSite: F (4.088, 1.363, 1.363) [0.75, 0.25, 0.25]
# PeriodicSite: F (4.088, 1.363, 4.088) [0.75, 0.25, 0.75]
# PeriodicSite: F (1.363, 4.088, 1.363) [0.25, 0.75, 0.25]
# PeriodicSite: F (4.088, 4.088, 1.363) [0.75, 0.75, 0.25]
# PeriodicSite: F (1.363, 1.363, 4.088) [0.25, 0.25, 0.75]
# PeriodicSite: F (1.363, 1.363, 1.363) [0.25, 0.25, 0.25]
# PeriodicSite: F (4.088, 4.088, 4.088) [0.75, 0.75, 0.75]

# %% [markdown]
# load QE input/output file

# %%
file = os.path.join(dpath, 'relax.in')
ios.read_qe.read_in(file)
# Out:
# Atoms(symbols='HCa32F64', pbc=True, cell=[10.9019002914, 10.9019002914, 10.9019002914], initial_magmoms=...)

# %%
file = os.path.join(dpath, 'relax.out')
ios.read_qe.read_out(file)
# Out:
# Atoms(symbols='HCa32F64', pbc=True, cell=[10.901900350679567, 10.901900350679567, 10.901900350679567], calculator=SinglePointDFTCalculator(...))

# %%
file = os.path.join(dpath, 'relax.in')
qe.read_in(file)
# Out:
# Atoms(symbols='HCa32F64', pbc=True, cell=[10.9019002914, 10.9019002914, 10.9019002914], initial_magmoms=...)

# %%
file = os.path.join(dpath, 'relax.out')
qe.read_out(file)
# Out:
# Atoms(symbols='HCa32F64', pbc=True, cell=[10.901900350679567, 10.901900350679567, 10.901900350679567], calculator=SinglePointDFTCalculator(...))

# %%
file = os.path.join(dpath, 'relax.in')
read_from_file(file, format='espresso-in')
# Out:
# Atoms(symbols='HCa32F64', pbc=True, cell=[10.9019002914, 10.9019002914, 10.9019002914], initial_magmoms=...)

# %%
file = os.path.join(dpath, 'relax.out')
atoms = read_from_file(file, format='espresso-out', index=-1)

# %% [markdown]
# convert ase to pymatgen

# %%
rlx = AseAtomsAdaptor.get_structure(atoms)
rlx
# Out:
# Structure Summary
# Lattice
#     abc : 10.901900350679567 10.901900350679567 10.901900350679567
#  angles : 90.0 90.0 90.0
#  volume : 1295.7064600901604
#       A : np.float64(10.901900350679567) np.float64(0.0) np.float64(0.0)
#       B : np.float64(0.0) np.float64(10.901900350679567) np.float64(0.0)
#       C : np.float64(0.0) np.float64(0.0) np.float64(10.901900350679567)
#     pbc : True True True
# PeriodicSite: Ca (2.969, 2.969, 2.725) [0.2723, 0.2723, 0.25]
# PeriodicSite: Ca (8.174, 8.174, 8.176) [0.7498, 0.7498, 0.75]
# PeriodicSite: Ca (8.121, 8.121, 2.726) [0.7449, 0.7449, 0.25]
# PeriodicSite: Ca (2.723, 2.723, 8.176) [0.2498, 0.2498, 0.75]
# PeriodicSite: Ca (8.172, 2.729, 8.176) [0.7496, 0.2504, 0.75]
# PeriodicSite: Ca (2.715, 8.182, 2.726) [0.2491, 0.7505, 0.25]
# PeriodicSite: Ca (2.729, 8.172, 8.176) [0.2504, 0.7496, 0.75]
# PeriodicSite: Ca (8.182, 2.715, 2.726) [0.7505, 0.2491, 0.25]
# PeriodicSite: Ca (2.732, 5.477, 5.48) [0.2506, 0.5024, 0.5026]
# PeriodicSite: Ca (8.151, -0.006704, -0.02879) [0.7476, -0.000615, -0.002641]
# PeriodicSite: Ca (8.151, -0.006711, 5.48) [0.7476, -0.0006156, 0.5026]
# PeriodicSite: Ca (2.732, 5.477, -0.02879) [0.2506, 0.5024, -0.00264]
# PeriodicSite: Ca (8.177, 5.451, -0.007692) [0.75, 0.5, -0.0007056]
# PeriodicSite: Ca (2.765, -0.03976, 5.474) [0.2537, -0.003647, 0.5021]
# PeriodicSite: Ca (2.765, -0.03974, -0.023) [0.2537, -0.003646, -0.00211]
# PeriodicSite: Ca (8.177, 5.451, 5.459) [0.75, 0.5, 0.5007]
# PeriodicSite: Ca (5.477, 2.732, 5.48) [0.5024, 0.2506, 0.5026]
# PeriodicSite: Ca (-0.006704, 8.151, -0.02879) [-0.000615, 0.7476, -0.002641]
# PeriodicSite: Ca (-0.006711, 8.151, 5.48) [-0.0006156, 0.7476, 0.5026]
# PeriodicSite: Ca (5.477, 2.732, -0.02879) [0.5024, 0.2506, -0.00264]
# PeriodicSite: Ca (-0.03974, 2.765, -0.023) [-0.003646, 0.2537, -0.00211]
# PeriodicSite: Ca (5.451, 8.177, 5.459) [0.5, 0.75, 0.5007]
# PeriodicSite: Ca (5.451, 8.177, -0.007692) [0.5, 0.75, -0.0007056]
# PeriodicSite: Ca (-0.03976, 2.765, 5.474) [-0.003647, 0.2537, 0.5021]
# PeriodicSite: Ca (5.506, 5.506, 2.726) [0.5051, 0.5051, 0.25]
# PeriodicSite: Ca (0.002006, 0.002006, 8.176) [0.000184, 0.000184, 0.75]
# PeriodicSite: Ca (-0.2431, -0.2431, 2.725) [-0.0223, -0.0223, 0.25]
# PeriodicSite: Ca (5.453, 5.453, 8.176) [0.5002, 0.5002, 0.75]
# PeriodicSite: Ca (-0.00383, 5.456, 8.176) [-0.0003513, 0.5004, 0.75]
# PeriodicSite: Ca (5.446, 0.01023, 2.726) [0.4995, 0.000938, 0.25]
# PeriodicSite: Ca (5.456, -0.00383, 8.176) [0.5004, -0.0003513, 0.75]
# PeriodicSite: Ca (0.01023, 5.446, 2.726) [0.000938, 0.4995, 0.25]
# PeriodicSite: F (1.427, 4.056, 4.092) [0.1309, 0.372, 0.3753]
# PeriodicSite: F (9.536, 6.816, 6.818) [0.8747, 0.6252, 0.6254]
# PeriodicSite: F (9.542, 6.778, 4.086) [0.8752, 0.6217, 0.3748]
# PeriodicSite: F (1.347, 4.087, 6.815) [0.1236, 0.3748, 0.6251]
# PeriodicSite: F (9.532, 4.095, 6.813) [0.8743, 0.3757, 0.625]
# PeriodicSite: F (1.363, 6.814, 4.094) [0.125, 0.625, 0.3755]
# PeriodicSite: F (1.363, 6.814, 6.821) [0.125, 0.625, 0.6257]
# PeriodicSite: F (9.567, 4.061, 4.086) [0.8775, 0.3725, 0.3748]
# PeriodicSite: F (4.056, 1.427, 4.092) [0.372, 0.1309, 0.3753]
# PeriodicSite: F (6.816, 9.536, 6.818) [0.6252, 0.8747, 0.6254]
# PeriodicSite: F (4.095, 9.532, 6.813) [0.3757, 0.8743, 0.625]
# PeriodicSite: F (6.814, 1.363, 4.094) [0.625, 0.125, 0.3755]
# PeriodicSite: F (6.778, 9.542, 4.086) [0.6217, 0.8752, 0.3748]
# PeriodicSite: F (4.087, 1.347, 6.815) [0.3748, 0.1236, 0.6251]
# PeriodicSite: F (6.814, 1.363, 6.821) [0.625, 0.125, 0.6257]
# PeriodicSite: F (4.061, 9.567, 4.086) [0.3725, 0.8775, 0.3748]
# PeriodicSite: F (4.181, 4.181, 1.331) [0.3835, 0.3835, 0.1221]
# PeriodicSite: F (6.814, 6.814, 9.538) [0.625, 0.625, 0.8749]
# PeriodicSite: F (6.812, 4.091, 9.535) [0.6248, 0.3753, 0.8746]
# PeriodicSite: F (4.086, 6.849, 1.365) [0.3748, 0.6283, 0.1252]
# PeriodicSite: F (4.091, 6.812, 9.535) [0.3753, 0.6248, 0.8746]
# PeriodicSite: F (6.849, 4.086, 1.365) [0.6283, 0.3748, 0.1252]
# PeriodicSite: F (6.814, 6.814, 1.348) [0.625, 0.625, 0.1236]
# PeriodicSite: F (4.076, 4.076, 9.533) [0.3739, 0.3739, 0.8744]
# PeriodicSite: F (9.551, 9.551, 9.533) [0.8761, 0.8761, 0.8744]
# PeriodicSite: F (9.551, 9.551, 6.82) [0.8761, 0.8761, 0.6256]
# PeriodicSite: F (1.363, 6.814, 9.532) [0.125, 0.625, 0.8743]
# PeriodicSite: F (9.536, 6.816, 9.535) [0.8747, 0.6252, 0.8746]
# PeriodicSite: F (1.378, 9.541, 6.815) [0.1264, 0.8752, 0.6251]
# PeriodicSite: F (1.378, 9.541, 9.538) [0.1264, 0.8752, 0.8749]
# PeriodicSite: F (4.076, 4.076, 6.82) [0.3739, 0.3739, 0.6256]
# PeriodicSite: F (6.814, 1.363, 9.532) [0.625, 0.125, 0.8743]
# PeriodicSite: F (4.087, 1.347, 9.538) [0.3748, 0.1236, 0.8749]
# PeriodicSite: F (6.812, 4.091, 6.818) [0.6248, 0.3753, 0.6254]
# PeriodicSite: F (4.086, 6.849, 4.086) [0.3748, 0.6283, 0.3748]
# PeriodicSite: F (6.778, 9.542, 1.365) [0.6217, 0.8752, 0.1252]
# PeriodicSite: F (4.061, 9.567, 1.365) [0.3725, 0.8775, 0.1252]
# PeriodicSite: F (6.814, 6.814, 4.103) [0.625, 0.625, 0.3764]
# PeriodicSite: F (1.347, 4.087, 9.538) [0.1236, 0.3748, 0.8749]
# PeriodicSite: F (4.091, 6.812, 6.818) [0.3753, 0.6248, 0.6254]
# PeriodicSite: F (6.816, 9.536, 9.535) [0.6252, 0.8747, 0.8746]
# PeriodicSite: F (9.541, 1.378, 6.815) [0.8752, 0.1264, 0.6251]
# PeriodicSite: F (9.541, 1.378, 9.538) [0.8752, 0.1264, 0.8749]
# PeriodicSite: F (6.849, 4.086, 4.086) [0.6283, 0.3748, 0.3748]
# PeriodicSite: F (9.542, 6.778, 1.365) [0.8752, 0.6217, 0.1252]
# PeriodicSite: F (9.567, 4.061, 1.365) [0.8775, 0.3725, 0.1252]
# PeriodicSite: F (1.298, 9.572, 4.092) [0.1191, 0.878, 0.3753]
# PeriodicSite: F (9.572, 1.298, 4.092) [0.878, 0.1191, 0.3753]
# PeriodicSite: F (9.447, 9.447, 1.331) [0.8665, 0.8665, 0.1221]
# PeriodicSite: F (1.427, 4.056, 1.359) [0.1309, 0.372, 0.1247]
# PeriodicSite: F (1.363, 6.814, 1.357) [0.125, 0.625, 0.1245]
# PeriodicSite: F (9.532, 4.095, 9.54) [0.8743, 0.3757, 0.875]
# PeriodicSite: F (1.363, 1.363, 3.861) [0.125, 0.125, 0.3542]
# PeriodicSite: F (1.363, 1.363, 6.723) [0.125, 0.125, 0.6167]
# PeriodicSite: F (9.447, 9.447, 4.12) [0.8665, 0.8665, 0.3779]
# PeriodicSite: F (4.056, 1.427, 1.359) [0.372, 0.1309, 0.1247]
# PeriodicSite: F (6.814, 1.363, 1.357) [0.625, 0.125, 0.1245]
# PeriodicSite: F (4.095, 9.532, 9.54) [0.3757, 0.8743, 0.875]
# PeriodicSite: F (1.298, 9.572, 1.359) [0.1191, 0.878, 0.1247]
# PeriodicSite: F (1.363, 1.363, 9.63) [0.125, 0.125, 0.8833]
# PeriodicSite: F (4.181, 4.181, 4.12) [0.3835, 0.3835, 0.3779]
# PeriodicSite: F (9.572, 1.298, 1.359) [0.878, 0.1191, 0.1247]
# PeriodicSite: F (1.363, 1.363, 1.591) [0.125, 0.125, 0.1459]
# PeriodicSite: F (6.814, 6.814, 6.815) [0.625, 0.625, 0.6251]
# PeriodicSite: H (1.363, 1.363, 2.726) [0.125, 0.125, 0.25]

# %% [markdown]
# convert pymatgen to ase

# %%
file=os.path.join(dpath, 'CaF2.vasp')
st = Structure.from_file(file)
atoms = AseAtomsAdaptor.get_atoms(st)
atoms
# Out:
# MSONAtoms(symbols='Ca4F8', pbc=True, cell=[5.4509501457, 5.4509501457, 5.4509501457])

# %% [markdown]
# load QE efg tensors from gipaw output file

# %%
file = os.path.join(dpath, 'V3Si_QE_EFG3x3x3_SITE_A.OUT')
efg_tensors = qe.read_efg(file)

efg_tensors[0]
# Out:
# array([[-8.62804611e+19,  0.00000000e+00, -1.14694029e+20],
#        [ 0.00000000e+00, -2.97322139e+20,  0.00000000e+00],
#        [-1.14694029e+20,  0.00000000e+00,  3.83602600e+20]])

# %% [markdown]
# load ELK output files: (geometry and EFG tensors)

# %%
file = os.path.join(dpath, 'MnSi_GEOMETRY.OUT')
elk.read_geom(file)
# Out:
# Atoms(symbols='Mn4Si4', pbc=True, cell=[4.566199937664733, 4.566199937664733, 4.566199937664733], initial_magmoms=...)

# %%
file = os.path.join(dpath, 'MnSi_EFG.OUT')
efg_tensors = elk.read_efg(file)

efg_tensors[0]
# Out:
# array([[-3.02274846e+04, -1.54534901e+20, -1.54534901e+20],
#        [-1.54534901e+20, -3.12190144e+05, -1.54534901e+20],
#        [-1.54534901e+20, -1.54534901e+20,  3.42417629e+05]])

# %% [markdown]
# remove numerical noise in efg tensors

# %%
remove_efg_noise=True
efg_noise_threshold=1e-8

tensors = []
for tensor in efg_tensors:
    if remove_efg_noise:
        max_element = np.max(np.abs(tensor))
        if max_element > 0:
            tensor[np.abs(tensor) < efg_noise_threshold * max_element] = 0.0
    tensors.append(tensor)

tensors[0]
# Out:
# array([[ 0.00000000e+00, -1.54534901e+20, -1.54534901e+20],
#        [-1.54534901e+20,  0.00000000e+00, -1.54534901e+20],
#        [-1.54534901e+20, -1.54534901e+20,  0.00000000e+00]])

# %% [markdown]
# query ALL 'relax' muon site calculations from a folder

# %%
folder = os.path.join(dpath, 'SZRO/query')

preview = True

pattern="*.out"
check_input = True
calc_types = "relax"


if preview:
    groups = get_relax_after_run(
        folder, 
        pattern=pattern, 
        check_input=check_input,
        calc_types=calc_types, 
        verbose=False,
    )
    print(f"\nPreview: {len(groups)} system group(s) found "
            f"(selection filters ignored in preview mode)\n")
    print_relax_summary(groups)


results = load_relax(
    path=folder,
    pattern=pattern,
    check_input=check_input,
    calc_types=calc_types,
    group_by_system=True,
    pymatgen=True,
    verbose=True,
    # **select_kwargs
)

file = 'SZRO_muonrelax_results.pkl'
file = os.path.join(dpath, file)
save_relax_results(results, file, fmt='pickle')
# Out:
# Preview: 1 system group(s) found (selection filters ignored in preview mode)
#
#   H-O-Re-Sr-Zn  nat = 161  ntyp = 5  -> 12 converged runs
#   ------------------------------------------
#   1 distinct system(s), 12 converged run(s) total
# Saved 12 result(s) to /home/misah/projects/muonscripts/examples/data/SZRO_muonrelax_results.pkl (pickle)

# %%
# folder = '/home/misah/projects/muonscripts/DATA/RVS'

# groups = get_relax_after_run(folder, check_input=True, calc_types='relax')
# print_relax_summary(groups)
# subset = None
# # subset = select_groups(groups, nat=(100, 200), min_runs=1)   # range + threshold, combinable
# subset = select_groups(groups, nat=(145, 145+1))   # range + threshold, combinable
# if subset:
#     print('='*50)
#     print_relax_summary(subset)


# results = load_relax(
#     path=folder,
#     pattern="*.out",
#     check_input=True,
#     calc_types="relax",
#     group_by_system=True,
#     pymatgen=True,
#     verbose=True,
#     # **select_kwargs
# )

# %%
# results[0]

# %%
# folder = '/home/misah/projects/muonscripts/DATA/RVS'
# folder = '/home/misah/projects/muonscripts/DATA/RVS/stable_sites_refined'

# groups = get_relax_after_run(folder, check_input=True, calc_types='relax')
# print_relax_summary(groups)
# subset = None
# # subset = select_groups(groups, nat=(100, 200), min_runs=1)   # range + threshold, combinable
# subset = select_groups(groups,)   # range + threshold, combinable
# if subset:
#     print_relax_summary(subset)


# results = load_relax(
#     path=folder,
#     pattern="*.out",
#     check_input=True,
#     calc_types="relax",
#     group_by_system=True,
#     pymatgen=True,
#     verbose=True,
#     # **select_kwargs
# )

# %%
# folder = '/home/misah/projects/muonscripts/DATA/RVS'
# folder = '/home/misah/projects/muonscripts/DATA/RVS/stable_sites_refined'
# folder = '/home/misah/projects/PERSONAL/DFT_MU/INITMU_vP_2x2x2/query'

# groups = get_relax_after_run(folder, check_input=True, calc_types='relax')
# print_relax_summary(groups)
# subset = None
# # subset = select_groups(groups, nat=(100, 200), min_runs=1)   # range + threshold, combinable
# subset = select_groups(groups,)   # range + threshold, combinable
# if subset:
#     print_relax_summary(subset)


# results = load_relax(
#     path=folder,
#     pattern="*.out",
#     check_input=True,
#     calc_types="relax",
#     group_by_system=True,
#     pymatgen=True,
#     verbose=True,
#     # **select_kwargs
# )

# %%
# results[0]

# %%
# import json, pickle
# from pymatgen.core import Structure

# file = 'SZRO_muRESULTS.json'
# file = os.path.join(dpath, file)
# with open(file, "r") as f:
#     json_data = json.load(f)

# file = 'SZRO_muRESULTS.pkl'
# file = os.path.join(dpath, file)
# with open(file, "rb") as f:
#     pkl_data = pickle.load(f)

# idx = 0

# pkl_data[idx]['rlxd_struct']

# entry = json_data[idx]['rlxd_struct']
# Structure.from_dict(entry["__pymatgen__"])
